# %%
import numpy as np
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (14,8)

# %%
import pandas as pd

# Lire le fichier CSV
data = pd.read_csv("cal_housing.csv")

data
# Out:
#        longitude  latitude  housingMedianAge  totalRooms  totalBedrooms  \
# 0        -122.23     37.88              41.0       880.0          129.0
# 1        -122.22     37.86              21.0      7099.0         1106.0
# 2        -122.24     37.85              52.0      1467.0          190.0
# 3        -122.25     37.85              52.0      1274.0          235.0
# 4        -122.25     37.85              52.0      1627.0          280.0
# ...          ...       ...               ...         ...            ...
# 20635    -121.09     39.48              25.0      1665.0          374.0
# 20636    -121.21     39.49              18.0       697.0          150.0
# 20637    -121.22     39.43              17.0      2254.0          485.0
# 20638    -121.32     39.43              18.0      1860.0          409.0
# 20639    -121.24     39.37              16.0      2785.0          616.0
#
#        population  households  medianIncome  medianHouseValue
# ...

# %%
data.describe()
# Out:
#           longitude      latitude  housingMedianAge    totalRooms  \
# count  20640.000000  20640.000000      20640.000000  20640.000000
# mean    -119.569704     35.631861         28.639486   2635.763081
# std        2.003532      2.135952         12.585558   2181.615252
# min     -124.350000     32.540000          1.000000      2.000000
# 25%     -121.800000     33.930000         18.000000   1447.750000
# 50%     -118.490000     34.260000         29.000000   2127.000000
# 75%     -118.010000     37.710000         37.000000   3148.000000
# max     -114.310000     41.950000         52.000000  39320.000000
#
#        totalBedrooms    population    households  medianIncome  \
# count   20640.000000  20640.000000  20640.000000  20640.000000
# mean      537.898014   1425.476744    499.539680      3.870671
# std       421.247906   1132.462122    382.329753      1.899822
# min         1.000000      3.000000      1.000000      0.499900
# ...

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housingMedianAge'}>],
#        [<Axes: title={'center': 'totalRooms'}>,
#         <Axes: title={'center': 'totalBedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'medianIncome'}>,
#         <Axes: title={'center': 'medianHouseValue'}>]], dtype=object)

# %%
col_target = "medianHouseValue"
data[col_target].hist(bins=100)
# Out:
# <Axes: >

# %%
data[col_target].value_counts()
# on peut voir que 965 quartier on 500001 dollars
# Out:
# medianHouseValue
# 500001.0    965
# 137500.0    122
# 162500.0    117
# 112500.0    103
# 187500.0     93
#            ...
# 359200.0      1
# 54900.0       1
# 377600.0      1
# 81200.0       1
# 47000.0       1
# Name: count, Length: 3842, dtype: int64

# %%
data[col_target].value_counts().sort_index()
# quand on les trie par ordre croissants o peut voir que la petite valeur c'est 14999 dollars et 4 Bien
# Out:
# medianHouseValue
# 14999.0       4
# 17500.0       1
# 22500.0       4
# 25000.0       1
# 26600.0       1
#            ...
# 498800.0      1
# 499000.0      1
# 499100.0      1
# 500000.0     27
# 500001.0    965
# Name: count, Length: 3842, dtype: int64

# %%
#une boite a moustache

data[col_target].plot.box()

# en vert il y a la median 50ù des données sont au dessus de ses valeurs et 50% en dessous de ses valeurs
#  donc dans la boite on a 50% des données
# Out:
# <Axes: >

# %%
#Pour la corrélation
data.corr()
# on peut voir qu'il y a pas de corrélation entre la longitude et le nombree de piece
# C'est pas parce que la longitude augmente que le nombre de piece va augmenter
# mais on peut voir que plus revenu medium augmente plus la valeur de la maison augmente donc très corréler
# Out:
#                   longitude  latitude  housingMedianAge  totalRooms  \
# longitude          1.000000 -0.924664         -0.108197    0.044568
# latitude          -0.924664  1.000000          0.011173   -0.036100
# housingMedianAge  -0.108197  0.011173          1.000000   -0.361262
# totalRooms         0.044568 -0.036100         -0.361262    1.000000
# totalBedrooms      0.068378 -0.066318         -0.320485    0.929893
# population         0.099773 -0.108785         -0.296244    0.857126
# households         0.055310 -0.071035         -0.302916    0.918484
# medianIncome      -0.015176 -0.079809         -0.119034    0.198050
# medianHouseValue  -0.045967 -0.144160          0.105623    0.134153
#
#                   totalBedrooms  population  households  medianIncome  \
# longitude              0.068378    0.099773    0.055310     -0.015176
# latitude              -0.066318   -0.108785   -0.071035     -0.079809
# housingMedianAge      -0.320485   -0.296244   -0.302916     -0.119034
# ...

# %%
import pandas as pd

corr = data.corr()

# Appliquer le style avec le gradient de couleur et formater les nombres à 2 décimales
corr = corr.style.background_gradient(cmap="coolwarm").format(precision=2)
corr
# Donc on peut voir que les valeurs qui sont prochent du rouge ou de 1 sont extremement correler
# Out:
# <style type="text/css">
# #T_a4227_row0_col0, #T_a4227_row1_col1, #T_a4227_row2_col2, #T_a4227_row3_col3, #T_a4227_row4_col4, #T_a4227_row5_col5, #T_a4227_row6_col6, #T_a4227_row7_col7, #T_a4227_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a4227_row0_col1, #T_a4227_row1_col0, #T_a4227_row1_col8, #T_a4227_row2_col3, #T_a4227_row2_col4, #T_a4227_row2_col5, #T_a4227_row2_col6, #T_a4227_row2_col7, #T_a4227_row3_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a4227_row0_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_a4227_row0_col3 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_a4227_row0_col4 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_a4227_row0_col5 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_a4227_row0_col6, #T_a4227_row1_col2 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_a4227_row0_col7 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# ...

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error


#modele seulement avec le medianIncome

X = data[["medianIncome"]]
y = data["medianHouseValue"]

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=31)

# Fit

Knn = KNeighborsRegressor()
Knn.fit(X_train , y_train)

#Predict train
y_test_pred = Knn.predict(X_test)

#performance
mae_test = mean_absolute_error(y_test, y_test_pred )

print("MAE test: ", mae_test)
# Out:
# MAE test:  67003.8746124031

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error


#modele seulement avec le medianIncome

X = data[["medianIncome", "latitude"]]
y = data["medianHouseValue"]

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=31)

# Fit

Knn = KNeighborsRegressor()
Knn.fit(X_train , y_train)

#Predict train
y_test_pred = Knn.predict(X_test)

#performance
mae_test = mean_absolute_error(y_test, y_test_pred )

print("MAE test: ", mae_test)
# Out:
# MAE test:  56146.79389534884
